# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ### This assignment is an essential first step in learning Data Science, focusing on using Markdown and basic coding.

# %% [markdown]
# ### Programming Languages Used in Data Science:
#
# 1. Python
# 2. R
# 3. SQL

# %% [markdown]
# ### Top 5 Libraries Used in Data Science
#
# In Python:
# 1. Pandas
# 2. NumPy
# 3. Matplotlib
# 4. Scikit-learn
# 5. Seaborn
#
# In R:
# 1. ggplot2
# 2. dplyr
# 3. tidyr
# 4. caret
# 5. shiny

# %% [markdown]
# ### Data Science Tools
#
# 1. Jupyter Notebook
# 2. RStudio
# 3. VS Code
# 4. Apache Spark
# 5. Power BI

# %% [markdown]
# ### Examples of Arithmetic Expressions
# - **Addition:** `3 + 5 = 8`
# - **Subtraction:** `10 - 4 = 6`
# - **Multiplication:** `6 * 7 = 42`
# - **Division:** `20 / 4 = 5`
# - **Exponentiation:** `2 ** 3 = 8`

# %%
# Multiplication and Addition Example

a = 5
b = 3

multiplication = a * b
addition = a + b

print("Multiplication:", multiplication)
print("Addition:", addition)
# Out:
# Multiplication: 15
# Addition: 8

# %%
# Convert minutes to hours

minutes = 120  

# Convert to hours
hours = minutes / 60  

print(f"{minutes} minutes is equal to {hours} hours")
# Out:
# 120 minutes is equal to 2.0 hours

# %%
objectives = [
    "Understand the basics of Data Science",
    "Learn how to use Markdown and Python in Jupyter Notebook",
    "Practice arithmetic operations and data manipulation",
    "Familiarize with essential Data Science tools",
    
]

# Print objectives
for i, obj in enumerate(objectives, 1):
    print(f"{i}. {obj}")
# Out:
# 1. Understand the basics of Data Science
# 2. Learn how to use Markdown and Python in Jupyter Notebook
# 3. Practice arithmetic operations and data manipulation
# 4. Familiarize with essential Data Science tools

# %% [markdown]
# ### Sandra Cepeda
